# %%
# ML Final Project Visualizations
### Dataset source: Melbourne, Seattle, and Sydney

# Description: 
### To show a frequency diagram for the given attributes. Using bar charts, data is plotted.

import matplotlib.pyplot as plt
import mysklearn.myutils as myutils
import mysklearn.plot_utils as plot_utils
from mysklearn.mypytable import MyPyTable
import os
import copy

## Data cleaning is executing...
aus_header = ["Date","Location","MinTemp","MaxTemp","Rainfall","Evaporation","Sunshine","WindGustDir",
"WindGustSpeed","WindDir9am","WindDir3pm","WindSpeed9am","WindSpeed3pm","Humidity9am","Humidity3pm",
"Pressure9am","Pressure3pm","Cloud9am","Cloud3pm","Temp9am","Temp3pm","RainToday","RainTomorrow"]

data_name = os.path.join("input_data", "MelbourneparsedData.csv")
table = MyPyTable().load_from_file(data_name)
table.column_names = aus_header
table_copy = copy.deepcopy(table)
table_copy.remove_rows_with_missing_values()
table_copy.remove_rows_with_missing_values()
table_copy.remove_rows_with_missing_values()
MyPyTable.save_to_file(table_copy, data_name)

###parse rainToday's that are yes
###month values = month name (12 of them), month_counts = (counts of rainToday that are yes for each month)

### table with only yes' and no NA's
months, yes_col = myutils.get_aus_frequencies(table_copy, "RainToday")
# Out:
# .5, 17.4, 7.8, 1.2, 1.0, 'N', 22.0, 'W', 'WSW', 7.0, 11.0, 84.0, 67.0, 1019.8, 1017.6, 7.0, 7.0, 12.6, 16.0, 'Yes', 'Yes'], ['Jun-14', 'Melbourne', 12.6, 16.6, 3.2, 1.0, 0.2, 'WSW', 31.0, 'WSW', 'WSW', 19.0, 13.0, 93.0, 83.0, 1017.6, 1017.5, 8.0, 7.0, 13.6, 16.1, 'Yes', 'Yes'], ['Jun-14', 'Melbourne', 10.8, 18.6, 3.0, 1.2, 5.2, 'N', 37.0, 'N', 'N', 28.0, 19.0, 78.0, 60.0, 1024.2, 1023.0, 7.0, 7.0, 12.5, 17.6, 'Yes', 'Yes'], ['Jun-14', 'Melbourne', 11.9, 17.1, 5.2, 1.0, 3.2, 'SSE', 26.0, 'SW', 'S', 9.0, 15.0, 85.0, 68.0, 1029.1, 1028.6, 7.0, 6.0, 13.0, 14.8, 'Yes', 'No'], ['Jun-14', 'Melbourne', 10.4, 17.0, 2.4, 1.0, 4.6, 'W', 41.0, 'N', 'W', 24.0, 28.0, 87.0, 78.0, 1018.9, 1018.3, 7.0, 7.0, 10.7, 14.3, 'Yes', 'Yes'], ['Jun-14', 'Melbourne', 10.1, 16.3, 2.2, 0.8, 3.4, 'W', 31.0, 'WSW', 'SSW', 20.0, 11.0, 85.0, 61.0, 1028.6, 1029.1, 7.0, 7.0, 11.1, 15.4, 'Yes', 'No'], ['Jun-14', 'Melbourne', 7.1, 14.5, 4.6, 1.0, 4.6, 'WSW', 96.0, 'NNW', 'SW', 31.0, 48.0, 79.0, 57.0, 994.5, 1001.5, 8.0, 6.0, 8.7, 13.9, 'Yes', 'Yes'], ['Jun-14', 'Melbourne', 8.6, 16.0, 6.2, 3.6, 3.4, 'WNW', 54.0, 'W', 'W', 19.0, 22.0, 73.0, 64.0, 1011.8, 1012.6, 7.0, 7.0, 11.2, 14.6, 'Yes', 'No'], ['Jul-14', 'Melbourne', 7.7, 15.6, 4.6, 0.2, 2.7, 'W', 54.0, 'WNW', 'WSW', 26.0, 33.0, 72.0, 65.0, 1005.7, 1007.6, 7.0, 7.0, 10.1, 14.6, 'Yes', 'No'], ['Jul-14', 'Melbourne', 6.9, 13.4, 5.8, 0.8, 2.1, 'N', 37.0, 'N', 'N', 9.0, 24.0, 88.0, 61.0, 1032.9, 1028.0, 7.0, 7.0, 9.5, 13.0, 'Yes', 'No'], ['Jul-14', 'Melbourne', 9.7, 14.7, 2.2, 1.4, 6.9, 'N', 57.0, 'N', 'NW', 24.0, 24.0, 78.0, 50.0, 1011.3, 1009.7, 7.0, 3.0, 10.7, 14.6, 'Yes', 'No'], ['Jul-14', 'Melbourne', 9.7, 16.9, 1.4, 3.0, 9.6, 'N', 63.0, 'N', 'NNW', 50.0, 31.0, 60.0, 49.0, 1016.6, 1012.2, 3.0, 2.0, 11.4, 16.3, 'Yes', 'No'], ['Aug-14', 'Melbourne', 4.4, 16.8, 14.2, 2.4, 2.8, 'N', 35.0, 'N', 'WSW', 13.0, 24.0, 61.0, 47.0, 1033.4, 1031.7, 6.0, 7.0, 10.7, 15.7, 'Yes', 'No'], ['Aug-14', 'Melbourne', 5.8, 13.6, 8.4, 3.2, 7.2, 'S', 39.0, 'WSW', 'SSE', 9.0, 26.0, 83.0, 39.0, 1030.6, 1029.9, 7.0, 4.0, 7.9, 12.6, 'Yes', 'No'], ['Aug-14', 'Melbourne', 10.7, 13.9, 1.2, 0.2, 0.2, 'S', 31.0, 'SSE', 'S', 20.0, 20.0, 74.0, 60.0, 1024.8, 1023.7, 7.0, 7.0, 11.5, 13.2, 'Yes', 'No'], ['Aug-14', 'Melbourne', 10.7, 16.7, 1.4, 1.4, 3.5, 'W', 39.0, 'WSW', 'SSE', 13.0, 24.0, 84.0, 57.0, 1026.4, 1026.0, 7.0, 6.0, 12.0, 15.7, 'Yes', 'No'], ['Sep-14', 'Melbourne', 9.1, 16.4, 10.4, 2.2, 9.2, 'SSW', 54.0, 'WSW', 'S', 24.0, 37.0, 73.0, 49.0, 1017.9, 1019.7, 6.0, 6.0, 11.6, 13.9, 'Yes', 'No'], ['Sep-14', 'Melbourne', 11.4, 19.7, 2.0, 4.0, 8.1, 'WNW', 50.0, 'W', 'WNW', 26.0, 26.0, 53.0, 35.0, 1010.9, 1010.5, 2.0, 7.0, 14.3, 18.5, 'Yes', 'Yes'], ['Sep-14', 'Melbourne', 8.9, 16.7, 3.2, 1.0, 6.1, 'SW', 67.0, 'W', 'WSW', 31.0, 33.0, 65.0, 55.0, 1013.7, 1014.9, 6.0, 7.0, 12.8, 12.9, 'Yes', 'No'], ['Sep-14', 'Melbourne', 8.6, 15.7, 1.4, 2.0, 6.3, 'SSE', 39.0, 'SW', 'SSE', 24.0, 26.0, 64.0, 61.0, 1025.2, 1023.7, 5.0, 7.0, 12.1, 14.5, 'Yes', 'No'], ['Oct-14', 'Melbourne', 10.2, 16.7, 5.4, 8.0, 5.2, 'SSW', 69.0, 'WSW', 'S', 31.0, 28.0, 61.0, 46.0, 1012.0, 1013.0, 7.0, 7.0, 12.1, 15.5, 'Yes', 'Yes'], ['Oct-14', 'Melbourne', 8.6, 17.3, 7.4, 5.0, 9.5, 'SSE', 61.0, 'SSE', 'S', 30.0, 39.0, 58.0, 39.0, 1021.7, 1022.1, 7.0, 6.0, 12.3, 15.8, 'Yes', 'No'], ['Oct-14', 'Melbourne', 10.6, 18.4, 4.6, 2.4, 11.3, 'SSE', 31.0, 'ESE', 'SE', 19.0, 9.0, 51.0, 41.0, 1027.2, 1025.9, 6.0, 1.0, 13.2, 18.1, 'Yes', 'No'], ['Oct-14', 'Melbourne', 13.8, 20.0, 25.6, 9.4, 7.7, 'WSW', 70.0, 'WSW', 'WSW', 20.0, 46.0, 93.0, 51.0, 1005.1, 1008.4, 7.0, 6.0, 13.9, 17.0, 'Yes', 'Yes'], ['Oct-14', 'Melbourne', 11.5, 20.5, 3.6, 6.6, 7.4, 'W', 56.0, 'NW', 'WSW', 22.0, 31.0, 57.0, 44.0, 1011.4, 1012.7, 7.0, 7.0, 14.6, 19.5, 'Yes', 'No'], ['Nov-14', 'Melbourne', 11.8, 19.8, 12.0, 9.0, 0.2, 'S', 35.0, 'WSW', 'SSE', 13.0, 9.0, 57.0, 52.0, 1021.7, 1021.4, 7.0, 7.0, 14.8, 18.7, 'Yes', 'No'], ['Dec-14', 'Melbourne', 14.0, 21.8, 19.4, 1.6, 4.3, 'S', 33.0, 'SSE', 'S', 19.0, 24.0, 80.0, 58.0, 1009. ...
